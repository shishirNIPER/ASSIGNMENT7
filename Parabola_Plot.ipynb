# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-2,2,100)
y = x**2
P = np.array([0,3])
Q = np.array([0,3.00000164])

ax=plt.plot(x,y)
plt.grid()
plt.axis('equal')


bx=plt.scatter(Q[0],Q[1])
plt.text(Q[0]+0.1,Q[1]+0.1,"Q")
plt.scatter(P[0],P[1])
plt.text(P[0]+0.1,P[1]+0.1,"P")


plt.legend(['$y = x^2$'])
